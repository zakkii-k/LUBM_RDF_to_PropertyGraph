# %%
import rdflib
import json
import glob
# ファイルパスの設定
owl_file = 'path/to/owl'
ntriples_file = 'path/to/ntriples'
dir_path = 'path/to/output/directory'

# OWLグラフの読み込み
owl_graph = rdflib.Graph()
owl_graph.parse(owl_file, format='xml')

# RDFグラフの読み込み
g = rdflib.Graph()

for file in glob.glob(ntriples_file):
    g.parse(file, format='nt')

# %%
# クラス情報の抽出
class_labels = {}
dataTypeProperty = {}
objectProperty = {}
for subj, pred, obj in owl_graph:
    if str(subj).startswith('https://'):
        subj = rdflib.URIRef(str(subj).replace('https://', 'http://'))
    if str(pred).startswith('https://'):
        pred = rdflib.URIRef(str(pred).replace('https://', 'http://'))
    if str(obj).startswith('https://'):
        obj = rdflib.URIRef(str(obj).replace('https://', 'http://'))
    if pred == rdflib.RDF.type and obj == rdflib.OWL.Class:
        class_labels[str(subj)] = str(subj).split('#')[-1]
    elif pred == rdflib.RDF.type and obj == rdflib.OWL.DatatypeProperty:
        dataTypeProperty[str(subj)] = str(subj).split('#')[-1]
    elif pred == rdflib.RDF.type and (obj == rdflib.OWL.ObjectProperty or obj == rdflib.OWL.TransitiveProperty):
        objectProperty[str(subj)] = str(subj).split('#')[-1]
    # else:
    #     print("subj:", subj, "pred:", pred, "obj:", obj)
print(class_labels)
print(dataTypeProperty)
print(objectProperty)
# Out:
# {'http://swat.cse.lehigh.edu/onto/univ-bench.owl#PostDoc': 'PostDoc', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#UnofficialPublication': 'UnofficialPublication', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Faculty': 'Faculty', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Student': 'Student', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Employee': 'Employee', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Course': 'Course', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Dean': 'Dean', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#ConferencePaper': 'ConferencePaper', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Institute': 'Institute', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Book': 'Book', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Organization': 'Organization', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#College': 'College', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#TechnicalReport': 'TechnicalReport', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Specification': 'Specification', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#UndergraduateStudent': 'UndergraduateStudent', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Person': 'Person', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#SystemsStaff': 'SystemsStaff', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Program': 'Program', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#AssociateProfessor': 'AssociateProfessor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Work': 'Work', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#GraduateStudent': 'GraduateStudent', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#GraduateCourse': 'GraduateCourse', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Publication': 'Publication', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#TeachingAssistant': 'TeachingAssistant', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Article': 'Article', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#JournalArticle': 'JournalArticle', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Manual': 'Manual', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#AdministrativeStaff': 'AdministrativeStaff', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Software': 'Software', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#ResearchGroup': 'ResearchGroup', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Research': 'Research', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Department': 'Department', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#VisitingProfessor': 'VisitingProfessor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#AssistantProfessor': 'AssistantProfessor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Schedule': 'Schedule', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#ResearchAssistant': 'ResearchAssistant', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Lecturer': 'Lecturer', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Chair': 'Chair', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#ClericalStaff': 'ClericalStaff', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#University': 'University', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#FullProfessor': 'FullProfessor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Director': 'Director', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#Professor': 'Professor'}
# {'http://swat.cse.lehigh.edu/onto/univ-bench.owl#telephone': 'telephone', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#name': 'name', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#officeNumber': 'officeNumber', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#title': 'title', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#age': 'age', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#emailAddress': 'emailAddress', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#researchInterest': 'researchInterest'}
# {'http://swat.cse.lehigh.edu/onto/univ-bench.owl#tenured': 'tenured', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#hasAlumnus': 'hasAlumnus', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#publicationDate': 'publicationDate', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#teachingAssistantOf': 'teachingAssistantOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#subOrganizationOf': 'subOrganizationOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom': 'degreeFrom', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#takesCourse': 'takesCourse', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#headOf': 'headOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#doctoralDegreeFrom': 'doctoralDegreeFrom', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#publicationAuthor': 'publicationAuthor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#listedCourse': 'listedCourse', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#orgPublication': 'orgPublication', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf': 'teacherOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#publicationResearch': 'publicationResearch', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#affiliateOf': 'affiliateOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#affiliatedOrganizationOf': 'affiliatedOrganizationOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#member': 'member', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#memberOf': 'memberOf', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#softwareDocumentation': 'softwareDocumentation', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#advisor': 'advisor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#worksFor': 'worksFor', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#researchProject': 'researchProject', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#softwareVersion': 'softwareVersion', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#mastersDegreeFrom': 'mastersDegreeFrom', 'http://swat.cse.lehigh.edu/onto/univ-bench.owl#undergraduateDegreeFrom': 'undergraduateDegreeFrom'}

# %%
# property graph用のmap
node_map = {}
edge_map = {}
# データとidの
node_id_map = {}
edge_id_map = {}
next_node_id = 1
next_edge_id = 1

for subj, pred, obj in g:
    if str(subj).startswith("https://"):
        subj = rdflib.URIRef(str(subj).replace("https://", "http://"))
    if str(pred).startswith("https://"):
        pred = rdflib.URIRef(str(pred).replace("https://", "http://"))
    if str(obj).startswith("https://"):
        obj = rdflib.URIRef(str(obj).replace("https://", "http://"))
    subj = str(subj)
    pred = str(pred)
    obj = str(obj)
    if "file://" in subj or "file://" in pred or "file://" in obj:
        continue
    sub_id = -1
    pre_id = -1
    obj_id = -1
    if subj not in node_id_map: # subjが初めての時．
        node_id_map[subj] = next_node_id
        node_map[next_node_id] = {"id": next_node_id, "property": {"uri": subj}}
        sub_id = next_node_id
        next_node_id += 1
    else:
        sub_id = node_id_map[subj]
    
    if pred in objectProperty:  # predがproperty graphのエッジの役割の時．
        if obj not in node_id_map:  # objが既出の時．
            node_id_map[obj] = next_node_id
            node_map[next_node_id] = {"id": next_node_id, "property": {"uri": obj}}
            obj_id = next_node_id
            next_node_id += 1
        else:
            obj_id = node_id_map[obj]
        if (pred, sub_id, obj_id) not in edge_id_map:
            edge_id_map[(pred, sub_id, obj_id)] = next_edge_id
            edge_map[next_edge_id] = {
                "id": next_edge_id,
                "label": objectProperty[pred],
                "src": sub_id,
                "dst": obj_id,
                "property": {"uri": pred},
            }
            next_edge_id += 1
    elif pred in dataTypeProperty: # プロパティ．
        node_map[sub_id]["property"][dataTypeProperty[pred]] = obj
    elif "type" in str(pred):
        if "label" in node_map[sub_id]:
            node_map[sub_id]["label"].append(class_labels[obj])
        else:
            node_map[sub_id]["label"] = [class_labels[obj]]
    else:
        print("sub:", subj, "pred:", pred, "obj:", obj)

# %%
import json
import os

# ディレクトリが存在しない場合は作成
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
# ... existing code ...

# node_mapをリスト形式に変換
node_list = list(node_map.values())

# edge_mapをリスト形式に変換
edge_list = list(edge_map.values())

# node_listをjson形式で出力
with open(os.path.join(dir_path, "nodes.json"), "w") as nodes_file:
    json.dump(node_list, nodes_file, ensure_ascii=False, indent=4)

# edge_listをjson形式で出力
with open(os.path.join(dir_path, "edges.json"), "w") as edges_file:
    json.dump(edge_list, edges_file, ensure_ascii=False, indent=4)
